# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel('HR_DataSet.xlsx')

# %%
data.head()
# Out:
#    Late show up percentage  Project initiative percentage  \
# 0                 0.477912                       0.517593
# 1                 0.298068                       0.403864
# 2                 0.353470                       0.545904
# 3                 0.684900                       0.678940
# 4                 0.714167                       0.365101
#
#    Percentage of project delivery on time  Percentage of emails exchanged  \
# 0                                0.255846                        0.446856
# 1                                0.234836                        0.490999
# 2                                0.483996                        0.509837
# 3                                0.310686                        0.490986
# 4                                0.294082                        0.392456
#
#    Percentage of responsiveness  Percentage of professional email response  \
# 0                      0.348797                                   0.064235
# ...

# %%
data.shape
# Out:
# (1000, 11)

# %%
data.isna().sum()
# Out:
# Late show up percentage                            0
# Project initiative percentage                      0
# Percentage of project delivery on time             0
# Percentage of emails exchanged                     0
# Percentage of responsiveness                       0
# Percentage of professional email response          0
# Percentage of sharing ideas                        0
# Percentage of helping colleagues                   0
# Percentage of entrepreneurial posts on LinkedIn    0
# Percentage of Facebook comments                    0
# Quitting                                           0
# dtype: int64

# %%
data.describe()
# Out:
#        Late show up percentage  Project initiative percentage  \
# count              1000.000000                    1000.000000
# mean                  0.501025                       0.483284
# std                   0.187179                       0.184640
# min                   0.000000                       0.000000
# 25%                   0.367040                       0.359586
# 50%                   0.495075                       0.486289
# 75%                   0.639074                       0.622330
# max                   1.000000                       1.000000
#
#        Percentage of project delivery on time  Percentage of emails exchanged  \
# count                             1000.000000                     1000.000000
# mean                                 0.427376                        0.400711
# std                                  0.187881                        0.144444
# min                                  0.000000                        0.000000
# ...

# %%
fig, axes = plt.subplots(5,2, figsize=(12,12))

sns.histplot(data['Late show up percentage'], color='red',kde=True, ax = axes[0,0])
sns.histplot(data['Project initiative percentage'], color='olive',kde=True, ax =axes[0,1])
sns.histplot(data['Percentage of project delivery on time'],kde=True ,color='green', ax =axes[1,0])
sns.histplot(data['Percentage of emails exchanged'], color='cyan',kde=True ,ax =axes[1,1])
sns.histplot(data['Percentage of responsiveness'], color='brown',kde=True, ax =axes[2,0])
sns.histplot(data['Percentage of professional email response'], color='blue',kde=True ,ax =axes[2,1])
sns.histplot(data['Percentage of sharing ideas'], color='pink',kde=True, ax =axes[3,0])
sns.histplot(data['Percentage of helping colleagues'], color='purple',kde=True, ax =axes[3,1])
sns.histplot(data['Percentage of entrepreneurial posts on LinkedIn'], color='yellow',kde=True, ax =axes[4,0])
sns.histplot(data['Percentage of Facebook comments'], color='orange',kde=True, ax =axes[4,1])

plt.tight_layout()

# %%
fig, axes = plt.subplots(5,2, figsize=(12,12))

sns.boxplot(data['Late show up percentage'], color='red', ax = axes[0,0])
sns.boxplot(data['Project initiative percentage'], color='olive', ax =axes[0,1])
sns.boxplot(data['Percentage of project delivery on time'] ,color='green', ax =axes[1,0])
sns.boxplot(data['Percentage of emails exchanged'], color='cyan',ax =axes[1,1])
sns.boxplot(data['Percentage of responsiveness'], color='brown', ax =axes[2,0])
sns.boxplot(data['Percentage of professional email response'], color='blue' ,ax =axes[2,1])
sns.boxplot(data['Percentage of sharing ideas'], color='pink', ax =axes[3,0])
sns.boxplot(data['Percentage of helping colleagues'], color='purple', ax =axes[3,1])
sns.boxplot(data['Percentage of entrepreneurial posts on LinkedIn'], color='yellow', ax =axes[4,0])
sns.boxplot(data['Percentage of Facebook comments'], color='orange', ax =axes[4,1])

plt.tight_layout()
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
fig, axes = plt.subplots(5,2, figsize=(12,12))

sns.violinplot(data['Late show up percentage'], color='red', ax = axes[0,0])
sns.violinplot(data['Project initiative percentage'], color='olive', ax =axes[0,1])
sns.violinplot(data['Percentage of project delivery on time'] ,color='green', ax =axes[1,0])
sns.violinplot(data['Percentage of emails exchanged'], color='cyan',ax =axes[1,1])
sns.violinplot(data['Percentage of responsiveness'], color='brown', ax =axes[2,0])
sns.violinplot(data['Percentage of professional email response'], color='blue' ,ax =axes[2,1])
sns.violinplot(data['Percentage of sharing ideas'], color='pink', ax =axes[3,0])
sns.violinplot(data['Percentage of helping colleagues'], color='purple', ax =axes[3,1])
sns.violinplot(data['Percentage of entrepreneurial posts on LinkedIn'], color='yellow', ax =axes[4,0])
sns.violinplot(data['Percentage of Facebook comments'], color='orange', ax =axes[4,1])

plt.tight_layout()
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
# Correlation between variables

sns.heatmap(data.corr(), annot=True, linecolor='white', cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Prepare the dataset for machine learning

# %%
# X = features 
# Y = target 

X = data.iloc[:,:-1]
Y=data.iloc[:,-1]

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# Name: Quitting, dtype: int64

# %%
X.head()
# Out:
#    Late show up percentage  Project initiative percentage  \
# 0                 0.477912                       0.517593
# 1                 0.298068                       0.403864
# 2                 0.353470                       0.545904
# 3                 0.684900                       0.678940
# 4                 0.714167                       0.365101
#
#    Percentage of project delivery on time  Percentage of emails exchanged  \
# 0                                0.255846                        0.446856
# 1                                0.234836                        0.490999
# 2                                0.483996                        0.509837
# 3                                0.310686                        0.490986
# 4                                0.294082                        0.392456
#
#    Percentage of responsiveness  Percentage of professional email response  \
# 0                      0.348797                                   0.064235
# ...

# %% [markdown]
# ## Train_Test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3, random_state=42)

# %% [markdown]
# ## Build the ML model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
model = LogisticRegression()

# train the model

model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#test the model

y_pred = model.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       142
#            1       0.96      0.96      0.96       158
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.96      0.96       300
# weighted avg       0.96      0.96      0.96       300

# %%
pd.crosstab(y_test,y_pred)
# Out:
# col_0       0    1
# Quitting
# 0         136    6
# 1           7  151

# %% [markdown]
# The accuracy of the model is 96%
